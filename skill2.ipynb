# %% [markdown]
# <a href="https://colab.research.google.com/github/rithwikkolluri-coder/ML-practical-lab-experiments-report/blob/main/skill2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv("game_dataset.csv")
df.columns = df.columns.str.strip() # Strip whitespace from column names

import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(6,4))

sns.countplot(data=df, x="Platform")

plt.title("Placement Count by Platform")
plt.xlabel("Platform")
plt.ylabel("Count")

plt.show()

plt.figure(figsize=(6,4))

plt.hist(df["Global_Sales"].dropna(),
         bins=15,
         color="skyblue",
         edgecolor="black")

plt.title("Global Sales Distribution")
plt.xlabel("Global Sales")
plt.ylabel("Frequency")

plt.show()

plt.figure(figsize=(6,5))

numeric_df = df.select_dtypes(include="number")

corr_matrix = numeric_df.corr()

sns.heatmap(corr_matrix,
            annot=True,
            cmap="coolwarm",
            fmt=".2f")

plt.title("Correlation Heatmap")

plt.show()
